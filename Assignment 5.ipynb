# %% [markdown]
# ***Guess a number is a game that prompts a player to guess a number between 0 and 9, which
# is randomly generated by the system. When the input given by the user matches the
# number generated by the system then the user wins. The game should go as follows:***
#  - Guess the number: 5
#  - Sorry, try again
#  - Guess the number: 3
#  - Sorry, try again
#  - Guess the number: 8
#  - You got it right! Congo!

# %%
import random
rn=random.randint(0,9)   #
i = 0
while i<3:
    gn=eval(input("Enter a number between 0 to 9 :"))
    if 0<=gn<=9:
        if rn==gn:
            print("You got it right! Congo!")
            break
        else:
            print("sorry, try again")
        i+=1
# Out:
# Enter a number between 0 to 9 :1
# You got it right! Congo!

# %% [markdown]
# **Make an improvement to the Guess a number game. Guide the user where they are
# standing and limit the number of attempts to 3. For example, the game should go like this:**
#  - Guess the number: 4
#  - Too low
#  - Guess the number: 9
#  - Too high
#  - Guess the number: 5
#  - Sorry you Lost!

# %%
import random
rn1=random.randint(0,9)
i1 = 0
while i1<3:
    gn1=eval(input("Enter a number between 0 to 9 :"))
    if 0<=gn1<=9:
        if rn1==gn1:                     #if guess number is equal to random no program will break
            print("You got it right! Congo!")
            break

        if i1==2:                       #after three chanses game will be over if not won
            print("Sorry you Lost!")
            break

        if gn1+1<=rn1:                 #if guess no is low so print low
            print("Too low, Try again")

        else:                          ##if guess no is high so print high
            print("Too high, , Try again")

        i1+=1
    else:
        print("Please enter a number between 0 and 9.")
# Out:
# Enter a number between 0 to 9 :5
# Too high, , Try again
# Enter a number between 0 to 9 :2
# Too high, , Try again
# Enter a number between 0 to 9 :1
# You got it right! Congo!

# %% [markdown]
# **Let us make the above game a little more interesting by converting it into a gambling
# problem. Suppose that a player starts with Rs. 1,000. If a player can guess the number in his
# first chance, then he will be given a prize of Rs. 5,000, if he requires 2 attempts then he will
# get a prize of Rs.1,000. If he loses then he will lose Rs. 500. For example the game should go
# like this:**
#
#  - You have a cash of Rs. 1,000 with you...
#  - Guess the number: 8
#  - Too high
#  - Guess the number: 3
#  - You have just won Rs. 1,000
#
#  - Your balance: Rs. 2000

# %%
import random
rn2=random.randint(0,9)
cash=1000
i2 = 0
while i2<3:
    gn2=eval(input("Enter a number between 0 to 9 :"))
    if 0<=gn1<=9:
        if rn2==gn2:
            if i2==0: 
                cash=cash+5000
                print("You have just won Rs. 5,000 Rupees")
            elif i2==1:
                cash=cash+1000
                print("You have just won Rs. 1,000 Rupees")
            else: 
                cash=cash+500
                print("You have just won Rs. 5,00 Rupees")
            break
                
        if i2==2:                       #after three chanses game will be over if not won
            print("Sorry you Lost!")
            cash=cash-500
            break

        if gn2+1<=rn2:                 #if guess no is low so print low
            print("Too low, Try again")

        else:                          ##if guess no is high so print high
            print("Too high, , Try again")

        
        i2+=1

    else:
        print("Please enter a number between 0 and 9.")
print("Your Balance Rupees",cash)
# Out:
# Enter a number between 0 to 9 :5
# Too low, Try again
# Enter a number between 0 to 9 :7
# You have just won Rs. 1,000 Rupees
# Your Balance Rupees 2000

# %% [markdown]
# ***Suppose that a player wants to play a game which requires him Rs. 1,000 to start. If the
# current balance in his account is less than Rs. 1,000 he needs to withdraw the extra money
# from his e-wallet***
#
# ***Note that if the sum of money in his courrent account and the amount withdrawn is greater than
# or equal to Rs. 1,000 then he can start playing the game. However if the sum is less than Rs.
# 1,000 then the program should keep displaying the user the message “You still do not have
# enough money to start playing.” and keep prompting the user to withdraw money unless it
# crosses Rs. 1,000. Once ready, i.e. if his current account balance crosses Rs. 1,000, it will display
# a message “Now, you are ready to play the game.” Your program should also display the account
# balance and the current amount in the e-wallet.***
#
# ***(consider: initial account balance is Rs. 200 and money in the e-wallet is Rs. 5,000)***
#
# ***(Do further improvement by checking if the e-wallet balance becomes NIL, etc.)***

# %%
current_acnt = 200
e_wallet = 5000
game_cost = 1000

while current_acnt < game_cost:
    deposit_amount = eval(input("You need to deposit money to start the game. Enter the amount to deposit: "))
    current_acnt += deposit_amount
    e_wallet-=deposit_amount

    print("Account Balance: Rs. {}".format(current_acnt))
    print("E-Wallet Balance: Rs. {}".format(e_wallet))

if e_wallet == 0:
    print("Warning: Your e-wallet balance is now NIL.")

print("Now, you are ready to play the game.")
# Out:
# You need to deposit money to start the game. Enter the amount to deposit: 5000
# Account Balance: Rs. 5200
# E-Wallet Balance: Rs. 0
# Warning: Your e-wallet balance is now NIL.
# Now, you are ready to play the game.
